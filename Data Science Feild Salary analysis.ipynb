# %% [markdown]
# # Web Scraping

# %%
from bs4 import BeautifulSoup as bs
import re
import requests

# %%
url="https://countrycode.org/"
req=requests.get(url)
req
# Out:
# <Response [200]>

# %%
soup=bs(req.content)
soup
# Out:
# <!DOCTYPE html>
# <!--[if IE 8]>         <html class="ie8" lang="en"> <![endif]--><!--[if IE 9]>         <html class="ie9" lang="en"> <![endif]--><!--[if gt IE 9]><!--><html lang="en"> <!--<![endif]-->
# <head>
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <meta content="IE=edge,chrome=1" http-equiv="X-UA-Compatible"/>
# <title>CountryCode.org: Country Codes, Phone Codes, Dialing Codes, Telephone Codes, ISO Country Codes</title>
# <meta content="width=device-width, initial-scale=1" name="viewport"/>
# <meta content="CountryCode.org: Country Codes, Phone Codes, Dialing Codes, Telephone Codes, ISO Country Codes" name="title"/>
# <meta content="Find more information about country codes, phone codes, and ISO country codes. We've got the phone codes you need for easy international calling!" name="description"/>
# <meta content="website" property="og:type"/>
# <meta content="CountryCode.org" property="og:site_name"/>
# ...

# %%
soup.findAll("td")
# Out:
# [<td><a href="/afghanistan">Afghanistan</a></td>,
#  <td>93</td>,
#  <td>AF / AFG</td>,
#  <td>29,121,286</td>,
#  <td>647,500</td>,
#  <td>20.65 Billion</td>,
#  <td><a href="/albania">Albania</a></td>,
#  <td>355</td>,
#  <td>AL / ALB</td>,
#  <td>2,986,952</td>,
#  <td>28,748</td>,
#  <td>12.8 Billion</td>,
#  <td><a href="/algeria">Algeria</a></td>,
#  <td>213</td>,
#  <td>DZ / DZA</td>,
#  <td>34,586,184</td>,
#  <td>2,381,740</td>,
#  <td>215.7 Billion</td>,
#  <td><a href="/americansamoa">American Samoa</a></td>,
#  <td>1-684</td>,
#  <td>AS / ASM</td>,
#  <td>57,881</td>,
#  <td>199</td>,
#  <td>462.2 Million</td>,
#  <td><a href="/andorra">Andorra</a></td>,
#  <td>376</td>,
#  <td>AD / AND</td>,
#  <td>84,000</td>,
#  <td>468</td>,
#  <td>4.8 Billion</td>,
#  <td><a href="/angola">Angola</a></td>,
#  <td>244</td>,
#  <td>AO / AGO</td>,
#  <td>13,068,161</td>,
#  <td>1,246,700</td>,
#  <td>124 Billion</td>,
#  <td><a href="/anguilla">Anguilla</a></td>,
#  <td>1-264</td>,
# ...

# %% [markdown]
# # Regex pattern for finding country and its code

# %%
country=[]
code=[]
count=0
for i in soup.findAll("td"):
    if count==6:
        count=0
    if count==0:
        val=re.sub('^<td>.+">|<.*>',"",str(i))
        country.append(val)
    elif count==2:
        val=re.sub('<td>|/.*</td>',"",str(i))
        code.append(val.rstrip())
    count+=1

# %%
country
# Out:
# ['Afghanistan',
#  'Albania',
#  'Algeria',
#  'American Samoa',
#  'Andorra',
#  'Angola',
#  'Anguilla',
#  'Antarctica',
#  'Antigua and Barbuda',
#  'Argentina',
#  'Armenia',
#  'Aruba',
#  'Australia',
#  'Austria',
#  'Azerbaijan',
#  'Bahamas',
#  'Bahrain',
#  'Bangladesh',
#  'Barbados',
#  'Belarus',
#  'Belgium',
#  'Belize',
#  'Benin',
#  'Bermuda',
#  'Bhutan',
#  'Bolivia',
#  'Bosnia and Herzegovina',
#  'Botswana',
#  'Brazil',
#  'British Indian Ocean Territory',
#  'British Virgin Islands',
#  'Brunei',
#  'Bulgaria',
#  'Burkina Faso',
#  'Burundi',
#  'Cambodia',
#  'Cameroon',
#  'Canada',
#  'Cape Verde',
#  'Cayman Islands',
#  'Central African Republic',
#  'Chad',
#  'Chile',
#  'China',
#  'Christmas Island',
#  'Cocos Islands',
#  'Colombia',
#  'Comoros',
#  'Cook Islands',
#  'Costa Rica',
#  'Croatia',
#  'Cuba',
#  'Curacao',
#  'Cyprus',
#  'Czech Republic',
#  'Democratic Republic of the Congo',
#  'Denmark',
#  'Djibouti',
#  'Dominica',
# ...

# %%
code
# Out:
# ['AF',
#  'AL',
#  'DZ',
#  'AS',
#  'AD',
#  'AO',
#  'AI',
#  'AQ',
#  'AG',
#  'AR',
#  'AM',
#  'AW',
#  'AU',
#  'AT',
#  'AZ',
#  'BS',
#  'BH',
#  'BD',
#  'BB',
#  'BY',
#  'BE',
#  'BZ',
#  'BJ',
#  'BM',
#  'BT',
#  'BO',
#  'BA',
#  'BW',
#  'BR',
#  'IO',
#  'VG',
#  'BN',
#  'BG',
#  'BF',
#  'BI',
#  'KH',
#  'CM',
#  'CA',
#  'CV',
#  'KY',
#  'CF',
#  'TD',
#  'CL',
#  'CN',
#  'CX',
#  'CC',
#  'CO',
#  'KM',
#  'CK',
#  'CR',
#  'HR',
#  'CU',
#  'CW',
#  'CY',
#  'CZ',
#  'CD',
#  'DK',
#  'DJ',
#  'DM',
#  'DO',
#  'TL',
#  'EC',
#  'EG',
#  'SV',
#  'GQ',
#  'ER',
#  'EE',
#  'ET',
#  'FK',
#  'FO',
#  'FJ',
#  'FI',
#  'FR',
#  'PF',
#  'GA',
#  'GM',
#  'GE',
#  'DE',
#  'GH',
#  'GI',
#  'GR',
#  'GL',
#  'GD',
#  'GU',
#  'GT',
#  'GG',
#  'GN',
#  'GW',
#  'GY',
#  'HT',
#  'HN',
#  'HK',
#  'HU',
#  'IS',
#  'IN',
#  'ID',
#  'IR',
#  'IQ',
#  'IE',
#  'IM',
#  'IL',
#  'IT',
#  'CI',
#  'JM',
#  'JP',
#  'JE',
#  'JO',
#  'KZ',
#  'KE',
#  'KI',
#  'XK',
# ...

# %% [markdown]
# # Import required libraries

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv(r"C:\Users\hemag\OneDrive\Desktop\datasets\salaries.csv")

# %%
df
# Out:
#        work_year experience_level employment_type             job_title  \
# 0           2020               EN              FT   Azure Data Engineer
# 1           2020               EN              CT    Staff Data Analyst
# 2           2020               SE              FT  Staff Data Scientist
# 3           2020               EN              FT          Data Analyst
# 4           2020               EX              FT        Data Scientist
# ...          ...              ...             ...                   ...
# 37229       2024               SE              FT          Data Analyst
# 37230       2024               SE              FT        Data Scientist
# 37231       2024               SE              FT        Data Scientist
# 37232       2024               SE              FT         Data Engineer
# 37233       2024               SE              FT         Data Engineer
#
#        salary salary_currency  salary_in_usd employee_residence  remote_ratio  \
# ...

# %% [markdown]
# # Data Cleaning

# %%
df.drop(["salary","salary_currency"],axis=1,inplace=True)

# %%
df.isnull().sum()
# Out:
# work_year             0
# experience_level      0
# employment_type       0
# job_title             0
# salary_in_usd         0
# employee_residence    0
# remote_ratio          0
# company_location      0
# company_size          0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 37234 entries, 0 to 37233
# Data columns (total 9 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   work_year           37234 non-null  int64
#  1   experience_level    37234 non-null  object
#  2   employment_type     37234 non-null  object
#  3   job_title           37234 non-null  object
#  4   salary_in_usd       37234 non-null  int64
#  5   employee_residence  37234 non-null  object
#  6   remote_ratio        37234 non-null  int64
#  7   company_location    37234 non-null  object
#  8   company_size        37234 non-null  object
# dtypes: int64(3), object(6)
# memory usage: 2.6+ MB

# %%
df.head()
# Out:
#    work_year experience_level employment_type             job_title  \
# 0       2020               EN              FT   Azure Data Engineer
# 1       2020               EN              CT    Staff Data Analyst
# 2       2020               SE              FT  Staff Data Scientist
# 3       2020               EN              FT          Data Analyst
# 4       2020               EX              FT        Data Scientist
#
#    salary_in_usd employee_residence  remote_ratio company_location  \
# 0         100000                 MU             0               MU
# 1          44753                 CA            50               CA
# 2         164000                 US            50               US
# 3          47899                 DE             0               DE
# 4         300000                 US           100               US
#
#   company_size
# 0            S
# 1            L
# 2            M
# 3            L
# 4            L

# %%
df["experience_level"]=df["experience_level"].map({"EN":"Entry-level","SE":"Senior-level",
                                                   "EX":"Executive-level","MI":"Mid-level"})
df["employment_type"]=df["employment_type"].map({"FT":"Full-time","CT":"Contract","PT":"Part-time","FL":"Freelance"})
df["company_size"]=df["company_size"].map({"S":"Small","L":"Large","M":"Medium"})
df["employee_residence"]=df["employee_residence"].map(dict(zip(code,country)))
df["company_location"]=df["company_location"].map(dict(zip(code,country)))

# %%
df
# Out:
#        work_year experience_level employment_type             job_title  \
# 0           2020      Entry-level       Full-time   Azure Data Engineer
# 1           2020      Entry-level        Contract    Staff Data Analyst
# 2           2020     Senior-level       Full-time  Staff Data Scientist
# 3           2020      Entry-level       Full-time          Data Analyst
# 4           2020  Executive-level       Full-time        Data Scientist
# ...          ...              ...             ...                   ...
# 37229       2024     Senior-level       Full-time          Data Analyst
# 37230       2024     Senior-level       Full-time        Data Scientist
# 37231       2024     Senior-level       Full-time        Data Scientist
# 37232       2024     Senior-level       Full-time         Data Engineer
# 37233       2024     Senior-level       Full-time         Data Engineer
#
#        salary_in_usd employee_residence  remote_ratio company_location  \
# ...

# %% [markdown]
# # Creating a new dataset

# %%
df.to_csv(r"C:\Users\hemag\OneDrive\Desktop\datasets\cleaned salary.csv",index=False) # Create a cleaned csv file

# %% [markdown]
# # Import the cleaned dataset

# %%
df=pd.read_csv(r"C:\Users\hemag\OneDrive\Desktop\datasets\cleaned salary.csv")
df.head()
# Out:
#    work_year experience_level employment_type             job_title  \
# 0       2020      Entry-level       Full-time   Azure Data Engineer
# 1       2020      Entry-level        Contract    Staff Data Analyst
# 2       2020     Senior-level       Full-time  Staff Data Scientist
# 3       2020      Entry-level       Full-time          Data Analyst
# 4       2020  Executive-level       Full-time        Data Scientist
#
#    salary_in_usd employee_residence  remote_ratio company_location  \
# 0         100000          Mauritius             0        Mauritius
# 1          44753             Canada            50           Canada
# 2         164000      United States            50    United States
# 3          47899            Germany             0          Germany
# 4         300000      United States           100    United States
#
#   company_size
# 0        Small
# 1        Large
# 2       Medium
# 3        Large
# 4        Large

# %%
df["work_year"].unique()
# Out:
# array([2020, 2021, 2022, 2023, 2024], dtype=int64)

# %% [markdown]
# # Data Visualization

# %%
plt.figure(figsize=(15,40))
for i,j in enumerate(df["work_year"].unique()):
    plt.subplot(5,1,i+1)
    ax=sns.countplot(x=df[df["work_year"]==j]["company_location"])
    for bars in ax.containers:
        ax.bar_label(bars)
    plt.title("Number of companies in each Country in the year "+str(j),fontsize=15,fontdict={"color":"green"})
    plt.xlabel("Number of companies in each country",fontsize=15,fontdict={"color":"blue"})
    plt.ylabel("count of companies",fontsize=15,fontdict={"color":"red"})
    plt.xticks(rotation=90)
plt.tight_layout(h_pad=3)    
plt.show()

# %%
comp_size=df.groupby(["work_year","company_size"])["job_title"].value_counts().reset_index().sort_values(by=["company_size","count"],ascending=[True,False])
comp_size
# Out:
#      work_year company_size                       job_title  count
# 372       2024        Large               Applied Scientist    244
# 208       2023        Large               Applied Scientist    169
# 373       2024        Large  Business Intelligence Engineer     90
# 209       2023        Large  Business Intelligence Engineer     76
# 374       2024        Large                  Data Scientist     65
# ..         ...          ...                             ...    ...
# 582       2024        Small              Analytics Engineer      1
# 583       2024        Small      Applied Research Scientist      1
# 584       2024        Small                 BI Data Analyst      1
# 585       2024        Small               Data Analyst Lead      1
# 586       2024        Small         Manager Data Management      1
#
# [587 rows x 4 columns]

# %%
fig,axes=plt.subplots(5,3,figsize=(30,43))
for i,year in enumerate(comp_size["work_year"].unique()):
    for j,size in enumerate(comp_size["company_size"].unique()):
        new=comp_size[(comp_size["work_year"] == year) & (comp_size["company_size"] == size)]
        num=sns.barplot(x=new["job_title"].head(),y=new["count"].head(),ax=axes[i,j])
        for bars in num.containers:
            num.bar_label(bars)
        axes[i,j].set_title("Top 5 job roles in "+size+" company in "+str(year),fontsize=20,fontdict={"color":"green"})
        axes[i,j].set_xlabel("Job title",fontsize=20,fontdict={"color":"blue"})
        axes[i,j].set_ylabel("Count",fontsize=20,fontdict={"color":"red"})
plt.tight_layout(h_pad=2)
plt.show()

# %%
plt.figure(figsize=(15,15))
c1=["#228B22","#FF8C00","#FFD700","#B22222"]
c2=["#87CEEB","#00FFFF","#008080","#20B2AA"]
for i,j in enumerate(df["work_year"].unique()):
    emp_level=df[df["work_year"]==j]["experience_level"].to_frame()["experience_level"].map({"Entry-level":1,"Mid-level":2,"Senior-level":3,"Executive-level":4}).value_counts().to_frame().reset_index()
    emp_level["label"]=emp_level["experience_level"].map({1:"Entry-level",2:"Mid-level",3:"Senior-level",4:"Executive-level"})
    plt.subplot(3,2,i+1)
    if i%2==0:
        c=c1
    else:
        c=c2
    plt.pie(x=emp_level["count"],labels=dict(zip(emp_level["label"],emp_level["experience_level"])),autopct="%1i%%",colors=c,wedgeprops={"edgecolor":"black"})
    plt.pie([1],colors="white",radius=0.7,wedgeprops={"edgecolor":"black"})
    plt.title("Trends of experience level in the year "+str(j))
plt.show()

# %%
plt.figure(figsize=(15,20))
for i,j in enumerate(df["work_year"].unique()):
    plt.subplot(5,1,i+1)
    vs=df[df["work_year"]==j]
    ax=sns.countplot(x=vs["experience_level"],hue=vs["employment_type"])
    for bars in ax.containers:
        ax.bar_label(bars)
    plt.title("Employment type in each experience level in "+str(j),fontsize=15,fontdict={"color":"green"})
    plt.xlabel("experience_level",fontsize=15,color="orange")
    plt.ylabel("Count",fontsize=15,color="red")
plt.tight_layout()    
plt.show()

# %%
resident=[]
for i in df["work_year"].unique():
    er=df[(df["work_year"]==i) & (df["employee_residence"]!=df["company_location"])].shape[0]
    resident.append(er)

# %%
resident
# Out:
# [9, 29, 40, 51, 6]

# %%
plt.plot(df["work_year"].unique(),resident,marker="X",markersize=10,color="red",linestyle="--")
for i,j in zip(df["work_year"].unique(),resident):
    plt.text(i+0.2,j,j)
plt.xticks(range(2019,2026,1))
plt.title("Work from home form the year 2020-2024",fontsize=15,fontdict={"color":"green"})
plt.xlabel("Year",fontsize=15,fontdict={"color":"orange"})
plt.ylabel("Count",fontsize=15,fontdict={"color":"red"})
plt.show()

# %%
ax=sns.countplot(x=df["work_year"],hue=df["remote_ratio"])
for bars in ax.containers:
    ax.bar_label(bars)
plt.title("Remote Ratio",fontsize=15,fontdict={"color":"green"})
plt.xlabel("Work year",fontsize=15,fontdict={"color":"orange"})
plt.ylabel("Count",fontsize=15,fontdict={"color":"red"})
plt.show()

# %%
col=["Reds","Greens","Oranges","Purples","Blues"]
plt.figure(figsize=(8,15))
for i,j in enumerate(df["work_year"].unique()):
    plt.subplot(5,1,i+1)
    top_5_sal=df.groupby(["work_year","job_title"])["salary_in_usd"].max().reset_index().sort_values(by=["work_year","salary_in_usd"],ascending=[True,False])
    ax=sns.barplot(x=top_5_sal[top_5_sal["work_year"]==j]["salary_in_usd"].head(),y=top_5_sal[top_5_sal["work_year"]==j]["job_title"].head(),orient="horizontal",palette=col[i])
    for bars in ax.containers:
        ax.bar_label(bars,padding=-40,color="white")
    plt.xticks([0,200000,400000,600000,800000])
    plt.title("Top 5 Highest paid jobs in "+str(j),fontsize=15,fontdict={"color":"green"})
    plt.xlabel("Salary in USD",fontsize=15,fontdict={"color":"orange"})
    plt.ylabel("Job title",fontsize=15,fontdict={"color":"red"})
plt.tight_layout()
plt.show()

# %%
max_sal=df.groupby(["experience_level","work_year"])["salary_in_usd"].max().reset_index()
max_sal
# Out:
#    experience_level  work_year  salary_in_usd
# 0       Entry-level       2020         250000
# 1       Entry-level       2021         225000
# 2       Entry-level       2022         200000
# 3       Entry-level       2023         350000
# 4       Entry-level       2024         774000
# 5   Executive-level       2020         325000
# 6   Executive-level       2021         416000
# 7   Executive-level       2022         324000
# 8   Executive-level       2023         465000
# 9   Executive-level       2024         526400
# 10        Mid-level       2020         450000
# 11        Mid-level       2021         423000
# 12        Mid-level       2022         430967
# 13        Mid-level       2023         750000
# 14        Mid-level       2024         800000
# 15     Senior-level       2020         412000
# 16     Senior-level       2021         276000
# 17     Senior-level       2022         405000
# 18     Senior-level       2023         750000
# ...

# %%
plt.figure(figsize=(10,15))
for i in max_sal["experience_level"].unique():
    year=max_sal[max_sal["experience_level"]==i]
    sns.lineplot(x=year["work_year"],y=year["salary_in_usd"],label=i,marker="D")  
    for j in range(len(year)):
        plt.text(year["work_year"].iloc[j]+0.03,year["salary_in_usd"].iloc[j],year["salary_in_usd"].iloc[j],fontsize=9)
plt.xticks([2020,2021,2022,2023,2024]) 
plt.title("MAX salary for experience level in each year",fontsize=15,fontdict={"color":"green"})
plt.xlabel("Work year",fontsize=15,fontdict={"color":"orange"})
plt.ylabel("Salary in USD",fontsize=15,fontdict={"color":"red"})
plt.grid()
plt.show()

# %%
min_sal=df.groupby(["experience_level","work_year"])["salary_in_usd"].min().reset_index()
min_sal
# Out:
#    experience_level  work_year  salary_in_usd
# 0       Entry-level       2020          15966
# 1       Entry-level       2021          15000
# 2       Entry-level       2022          15000
# 3       Entry-level       2023          16000
# 4       Entry-level       2024          16000
# 5   Executive-level       2020          15000
# 6   Executive-level       2021          69741
# 7   Executive-level       2022          76309
# 8   Executive-level       2023          55000
# 9   Executive-level       2024          41500
# 10        Mid-level       2020          20000
# 11        Mid-level       2021          16904
# 12        Mid-level       2022          15000
# 13        Mid-level       2023          15680
# 14        Mid-level       2024          16000
# 15     Senior-level       2020          33511
# 16     Senior-level       2021          18907
# 17     Senior-level       2022          25000
# 18     Senior-level       2023          15809
# ...

# %%
plt.figure(figsize=(10,10))
for i in min_sal["experience_level"].unique():
    year=min_sal[min_sal["experience_level"]==i]
    sns.lineplot(x=year["work_year"],y=year["salary_in_usd"],label=i,marker="D")  
    for j in range(len(year)):
        plt.text(year["work_year"].iloc[j]+0.03,year["salary_in_usd"].iloc[j],year["salary_in_usd"].iloc[j],fontsize=9)
plt.xticks([2020,2021,2022,2023,2024])  
plt.title("MIN salary for experience level in each year",fontsize=15,fontdict={"color":"green"})
plt.xlabel("Work year",fontsize=15,fontdict={"color":"orange"})
plt.ylabel("Salary in USD",fontsize=15,fontdict={"color":"red"})
plt.grid()
plt.show()
